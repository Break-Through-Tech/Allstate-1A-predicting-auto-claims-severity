# %%
import os

import pandas as pd
import numpy as np

# %%
# Expecting 70,025,339
actual_size = os.path.getsize('../../../data/allstate_claims_data.csv')
expected_size = 70025339

if actual_size == expected_size:
    print(f"Expected Size: {expected_size}")
    print(f"Actual Size: {actual_size}")
    print("Size matches!")
else:
    print(f"Expected Size: {expected_size}")
    print(f"Actual Size: {actual_size}")
    print("Size doesn't match!")
# Out:
# Expected Size: 70025339
# Actual Size: 70025339
# Size matches!

# %%
# Looking for (188318, 132)
source_identity = pd.read_csv('../../../data/allstate_claims_data.csv')
actual_shape = source_identity.shape
expected_shape = (188318, 132)

if actual_shape == expected_shape:
    print(f"Expected Shape: {expected_shape}")
    print(f"Actual Shape: {actual_shape}")
    print("Shape matches!")
else:
    print(f"Expected Shape: {expected_shape}")
    print(f"Actual Size: {actual_shape}")
    print("Shape doesn't match!")
# Out:
# Expected Shape: (188318, 132)
# Actual Shape: (188318, 132)
# Shape matches!
