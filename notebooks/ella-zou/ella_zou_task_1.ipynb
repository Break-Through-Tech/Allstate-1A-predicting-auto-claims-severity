# %%
import os
import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/shenqinmonb/Desktop/BTT/All State Project/Allstate-1A-predicting-auto-claims-severity/notebooks/September/Gate 1'

# %%
allstate_claims = pd.read_csv('/Users/shenqinmonb/Desktop/BTT/All State Project/Allstate-1A-predicting-auto-claims-severity/data/allstate_claims_data.csv')

# %%
allstate_claims.shape
# Out:
# (188318, 132)

# %%
file_size = os.path.getsize('/Users/shenqinmonb/Desktop/BTT/All State Project/Allstate-1A-predicting-auto-claims-severity/data/allstate_claims_data.csv')
file_size
# Out:
# 70025339
